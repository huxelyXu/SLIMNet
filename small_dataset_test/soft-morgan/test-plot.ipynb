# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas 
import seaborn as sns

# %%
x01 = np.array([0.29676, 0.29994, 0.30945, 0.31712, 0.30676])
x001 = np.array([0.28629, 0.29608, 0.29758, 0.29820, 0.29942])
x00001 = np.array([0.29790, 0.30055, 0.30131, 0.30853, 0.31062])
x1 = np.array([0.32794, 0.33278, 0.34078, 0.34859])
x10 = np.array([0.3378, 0.34098, 0.34079, 0.33535, 0.34614])
x100 = np.array([0.36597, 0.37580, 0.34, 0.41, 0.34])
x1000 = np.array([0.37288, 0.37805, 0.38949, 0.36494, 0.35])

# %%
x = [4, 2, 1, 0, -1, -2, -3]
y = [np.mean(x00001), np.mean(x001), np.mean(x01), np.mean(x1), np.mean(x10), np.mean(x100), np.mean(x1000)]
yerr = [np.var(x00001), np.var(x001), np.var(x01), np.var(x1), np.var(x10), np.var(x100), np.var(x1000)]
sns.set()
plt.figure(figsize = (5, 5))
# plt.scatter(x, y ,alpha = 0.5,marker='s'
#             ,cmap='viridis_r'
#            )
# plt.errorbar(x,y, yerr = yerr, elinewidth=2,alpha=1,ecolor = 'black',capsize=5,capthick=1
#              #,linestyle="none"
#             )

plt.errorbar(x,y,yerr=yerr,fmt='p',ecolor='r',color='b',elinewidth=2,capsize=7)
plt.plot(x, y, c='royalblue')
# plt.errorbar(x, y, yerr = yerr)
plt.savefig('tmp.png', dpi = 700)
plt.show()
